# %% [markdown]
# ## Reading the data present in text format and converting it into Dataframe

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
review=[]
for i in range(1,568454):
    with open("C:/Users/Admin/Desktop/txt_reviews/review_{}.txt".format(i),"r",encoding="utf-8") as f:
        review.append(f.readlines())

# %%
dataset = pd.DataFrame(review)

# %%
dataset
# Out:
#                               0                         1  \
# 0       ProductId: B001E4KFG0\n  UserId: A3SGXH7AUHU8GW\n
# 1       ProductId: B00813GRG4\n  UserId: A1D87F6ZCVE5NK\n
# 2       ProductId: B000LQOCH0\n   UserId: ABXLMWJIXXAIN\n
# 3       ProductId: B000UA0QIQ\n  UserId: A395BORC6FGVXV\n
# 4       ProductId: B006K2ZZ7K\n  UserId: A1UQRSCLF8GW1T\n
# ...                         ...                       ...
# 568448  ProductId: B001EO7N10\n  UserId: A1F6BHEYB7R6R7\n
# 568449  ProductId: B001EO7N10\n  UserId: A28KG5XORO54AY\n
# 568450  ProductId: B003S1WTCU\n  UserId: A3I8AFVPEE8KI5\n
# 568451  ProductId: B004I613EE\n  UserId: A121AA1GQV751Z\n
# 568452  ProductId: B004I613EE\n   UserId: A3IBEVCTXKNOH\n
#
#                                                      2  \
# 0                            ProfileName: delmartian\n
# 1                                ProfileName: dll pa\n
# 2       ProfileName: Natalia Corres "Natalia Corres"\n
# ...

# %%
dataset.to_csv('sentiment_analysis.csv')

# %%
df = pd.read_csv('sentiment_analysis.csv')

# %%
df
# Out:
#         Unnamed: 0                        0                         1  \
# 0                0  ProductId: B001E4KFG0\n  UserId: A3SGXH7AUHU8GW\n
# 1                1  ProductId: B00813GRG4\n  UserId: A1D87F6ZCVE5NK\n
# 2                2  ProductId: B000LQOCH0\n   UserId: ABXLMWJIXXAIN\n
# 3                3  ProductId: B000UA0QIQ\n  UserId: A395BORC6FGVXV\n
# 4                4  ProductId: B006K2ZZ7K\n  UserId: A1UQRSCLF8GW1T\n
# ...            ...                      ...                       ...
# 568448      568448  ProductId: B001EO7N10\n  UserId: A1F6BHEYB7R6R7\n
# 568449      568449  ProductId: B001EO7N10\n  UserId: A28KG5XORO54AY\n
# 568450      568450  ProductId: B003S1WTCU\n  UserId: A3I8AFVPEE8KI5\n
# 568451      568451  ProductId: B004I613EE\n  UserId: A121AA1GQV751Z\n
# 568452      568452  ProductId: B004I613EE\n   UserId: A3IBEVCTXKNOH\n
#
#                                                      2  \
# 0                            ProfileName: delmartian\n
# ...
